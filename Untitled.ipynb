# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.corpus import stopwords
import string

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv('spam.csv', encoding='latin1')
df.sample(5)
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 1417  ham  No wonder... Cos i dun rem seeing a silver car...        NaN
# 4685  ham                  But pls dont play in others life.        NaN
# 2460  ham  i cant talk to you now.i will call when i can....        NaN
# 1512  ham  Hey sweet, I was wondering when you had a mome...        NaN
# 4810  ham  E admin building there? I might b slightly ear...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 1417        NaN        NaN
# 4685        NaN        NaN
# 2460        NaN        NaN
# 1512        NaN        NaN
# 4810        NaN        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.drop(['Unnamed: 2','Unnamed: 3','Unnamed: 4'], axis=1,inplace=True)

# %%
df.head(4)
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...

# %%
df.rename(columns={'v1': 'Result', 'v2' :'text'},inplace=True)

# %%
df.head(3)
# Out:
#   Result                                               text
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...

# %%
from sklearn.preprocessing import LabelEncoder
Lb=LabelEncoder()

# %%
df['Result']=Lb.fit_transform(df['Result'])

# %%
df.head(5)
# Out:
#    Result                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# 0- It is for ham
# 1- It is for spam

# %%
df.isnull().sum()
# Out:
# Result    0
# text      0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    5169
# True      403
# dtype: int64

# %%
df.drop_duplicates(keep='first',inplace=True)

# %%
df.duplicated().value_counts()
# Out:
# False    5169
# dtype: int64

# %% [markdown]
# # EDA

# %%
df.Result.value_counts()
# Out:
# 0    4516
# 1     653
# Name: Result, dtype: int64

# %%
plt.pie(df['Result'].value_counts(),labels=['spam','hams'],autopct="%0.2f")
plt.show()

# %%
# !pip install nltk

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\User
# [nltk_data]     2\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df.text.head(5)
# Out:
# 0    Go until jurong point, crazy.. Available only ...
# 1                        Ok lar... Joking wif u oni...
# 2    Free entry in 2 a wkly comp to win FA Cup fina...
# 3    U dun say so early hor... U c already then say...
# 4    Nah I don't think he goes to usf, he lives aro...
# Name: text, dtype: object

# %%
df['num_character']=df['text'].apply(len)

# %%
df.head(4)
# Out:
#    Result                                               text  num_character
# 0       0  Go until jurong point, crazy.. Available only ...            111
# 1       0                      Ok lar... Joking wif u oni...             29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...            155
# 3       0  U dun say so early hor... U c already then say...             49

# %%
df['num_word']=df['text'].apply(lambda x: len(nltk.word_tokenize(x)))

# %%
df['num_sentences']=df['text'].apply(lambda x: len(nltk.sent_tokenize(x)))

# %%
df.sample(5)
# Out:
#       Result                                               text  \
# 3268       0                 Raviyog Peripherals bhayandar east
# 1794       0                   How much i gave to you. Morning.
# 1057       0                               Ard 515 like dat. Y?
# 974        0                           Eh u send wrongly lar...
# 1384       0  Storming msg: Wen u lift d phne, u say \HELLO\...
#
#       num_character  num_word  num_sentences
# 3268             34         4              1
# 1794             32         9              2
# 1057             20         7              2
# 974              24         6              1
# 1384            278        80              7

# %%
df[['num_character','num_word','num_sentences']].describe()
# Out:
#        num_character     num_word  num_sentences
# count    5169.000000  5169.000000    5169.000000
# mean       78.977945    18.453279       1.947185
# std        58.236293    13.324793       1.362406
# min         2.000000     1.000000       1.000000
# 25%        36.000000     9.000000       1.000000
# 50%        60.000000    15.000000       1.000000
# 75%       117.000000    26.000000       2.000000
# max       910.000000   220.000000      28.000000

# %%
sns.histplot(df[df['Result'] == 0]['num_character'])
sns.histplot(df[df['Result']==1]['num_character'], color= 'Red')
plt.show()

# %%
sns.histplot(df[df['Result'] == 0]['num_word'])
sns.histplot(df[df['Result']==1]['num_word'], color= 'Red')
plt.show()

# %%
sns.histplot(df[df['Result'] == 0]['num_sentences'])
sns.histplot(df[df['Result']==1]['num_sentences'], color= 'Red')
plt.show()

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Data preprocessing
# - Lower case
# - Tokenization
# - Removing special characters
# - Removing stop words and punctuation
# - Stemming

# %%
def preprocessing(text):
    text=text.lower()
    text=nltk.word_tokenize(text)
    
    y=[]
    for i in text:
        if i.isalnum():
            y.append(i)
    text=y[:]
    y.clear()
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
    text = y[:]
    y.clear()
    
    for i in text:
        y.append(ps.stem(i))
    return " ".join(y)

# %%
preprocessing('Go until jurong point, crazy 9% ? ')
# Out:
# 'go jurong point crazi 9'

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\User
# [nltk_data]     2\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.stem.porter import PorterStemmer

# %%
ps=PorterStemmer()
ps.stem('danceing')
# Out:
# 'danc'

# %%
df['transform_text']=df['text'].apply(preprocessing)

# %%
df.head(9)
# Out:
#    Result                                               text  num_character  \
# 0       0  Go until jurong point, crazy.. Available only ...            111
# 1       0                      Ok lar... Joking wif u oni...             29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...            155
# 3       0  U dun say so early hor... U c already then say...             49
# 4       0  Nah I don't think he goes to usf, he lives aro...             61
# 5       1  FreeMsg Hey there darling it's been 3 week's n...            148
# 6       0  Even my brother is not like to speak with me. ...             77
# 7       0  As per your request 'Melle Melle (Oru Minnamin...            160
# 8       1  WINNER!! As a valued network customer you have...            158
#
#    num_word  num_sentences                                     transform_text
# 0        24              2  go jurong point crazi avail bugi n great world...
# ...

# %%
from wordcloud import WordCloud
ws=WordCloud(width=500,height=500,min_font_size=10,background_color='black')

# %%
spam_wc = ws.generate(df[df['Result'] == 1]['transform_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(11,6))
plt.imshow(spam_wc)
plt.show()

# %%
ham_wc = ws.generate(df[df['Result'] == 0]['transform_text'].str.cat(sep=" "))
plt.figure(figsize=(11,6))
plt.imshow(spam_wc)
plt.show()

# %%
from collections import Counter

# %%
spam_corpus = []
for msg in df[df['Result'] == 1]['transform_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
sns.barplot(pd.DataFrame(Counter(spam_corpus).most_common(30))[0],pd.DataFrame(Counter(spam_corpus).most_common(30))[1])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\User 2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
hams_corpus = []
for msg in df[df['Result'] == 0]['transform_text'].tolist():
    for word in msg.split():
        hams_corpus.append(word)

# %%
sns.barplot(pd.DataFrame(Counter(hams_corpus).most_common(30))[0],pd.DataFrame(Counter(hams_corpus).most_common(30))[1])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\User 2\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Models

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv = CountVectorizer()
tfidf = TfidfVectorizer(max_features=3000)

# %%
X = tfidf.fit_transform(df['transform_text']).toarray()

# %%
X.shape
# Out:
# (5169, 3000)

# %%
y = df['Result'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.8694390715667312
# [[788 108]
#  [ 27 111]]
# 0.5068493150684932

# %%
mnb.fit(X_train,y_train)
y_pred1 = mnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.9709864603481625
# [[896   0]
#  [ 30 108]]
# 1.0

# %%
bnb.fit(X_train,y_train)
y_pred1 = bnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.9835589941972921
# [[895   1]
#  [ 16 122]]
# 0.991869918699187

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
# !pip install xgboost
# Out:
# ...
#      ---------------------------------------- 99.8/99.8 MB 5.3 MB/s eta 0:00:00
# ...

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver='liblinear', penalty='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
abc = AdaBoostClassifier(n_estimators=50, random_state=2)
bc = BaggingClassifier(n_estimators=50, random_state=2)

gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
xgb = XGBClassifier(n_estimators=50,random_state=2)

# %%
clfs = {
    'SVC' : svc,
    'KN' : knc, 
    'NB': mnb, 
    'DT': dtc, 
    'LR': lrc, 
    'RF': rfc, 
    'AdaBoost': abc, 
    'BgC': bc, 
    'GBDT':gbdt,
    'xgb':xgb
}

# %%
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)
    
    return accuracy,precision

# %%
accuracy_scores = []
precision_scores = []

for name,clf in clfs.items():
    
    current_accuracy,current_precision = train_classifier(clf, X_train,y_train,X_test,y_test)
    
    print("For ",name)
    print("Accuracy - ",current_accuracy)
    print("Precision - ",current_precision)
    
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# For  SVC
# Accuracy -  0.9758220502901354
# Precision -  0.9747899159663865
# C:\Users\User 2\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# For  KN
# Accuracy -  0.9052224371373307
# Precision -  1.0
# For  NB
# Accuracy -  0.9709864603481625
# Precision -  1.0
# For  DT
# Accuracy -  0.9284332688588007
# Precision -  0.82
# For  LR
# Accuracy -  0.9584139264990329
# Precision -  0.9702970297029703
# For  RF
# Accuracy -  0.9748549323017408
# Precision -  0.9827586206896551
# For  AdaBoost
# ...

# %%
import pickle
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(mnb,open('model.pkl','wb'))

# %%
df['transform_text'][2]
# Out:
# 'free entri 2 wkli comp win fa cup final tkt 21st may text fa 87121 receiv entri question std txt rate c appli 08452810075over18'

# %%
df.head(3)
# Out:
#    Result                                               text  num_character  \
# 0       0  Go until jurong point, crazy.. Available only ...            111
# 1       0                      Ok lar... Joking wif u oni...             29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...            155
#
#    num_word  num_sentences                                     transform_text
# 0        24              2  go jurong point crazi avail bugi n great world...
# 1         8              2                              ok lar joke wif u oni
# 2        37              2  free entri 2 wkli comp win fa cup final tkt 21...
